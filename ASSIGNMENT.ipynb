# %% [markdown]
# Prototype for Text or Photo to 3D Model Generator

# %%
# !pip install numpy==1.26.4

# %%
# !pip install trimesh pyrender

# %%
code = """
from text_to_3d import generate_3d_model_from_text
from viewer import display_3d_model

if __name__ == "__main__":
    prompt = input("Enter a text prompt: ")
    model_path = generate_3d_model_from_text(prompt)
    display_3d_model(model_path)
"""

with open("main.py", "w") as f:
    f.write(code)

# %%
def generate_3d_model_from_text(prompt):
    print(f"Generating 3D model for: '{prompt}'")
    dummy_model_path = "demo_model.obj"
    with open(dummy_model_path, "w") as f:
        f.write("# Dummy 3D Model\n")
        f.write("v 0 0 0\nv 1 0 0\nv 1 1 0\nv 0 1 0\nf 1 2 3 4\n")
    return dummy_model_path

import trimesh
import pyrender

def display_3d_model(model_path):
    mesh = trimesh.load(model_path)
    scene = pyrender.Scene()
    scene.add(pyrender.Mesh.from_trimesh(mesh))
    pyrender.Viewer(scene, use_raymond_lighting=True, run_in_thread=True)

prompt = "a simple cube"
model_path = generate_3d_model_from_text(prompt)
display_3d_model(model_path)
# Out:
# Generating 3D model for: 'a simple cube'
# Exception in thread Thread-11 (_init_and_start_app):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner

# %%
import os

def generate_3d_model_from_text(prompt):
    print(f"Generating 3D model for: '{prompt}'")

    # This part simulates model output.
    # Replace with Shap-E or other text-to-3D implementation
    dummy_model_path = "demo_model.obj"

    # Create a placeholder .obj file (replace this with real model generation)
    with open(dummy_model_path, "w") as f:
        f.write("# Dummy 3D Model\n")
        f.write("v 0 0 0\nv 1 0 0\nv 1 1 0\nv 0 1 0\nf 1 2 3 4\n")

    return dummy_model_path
# Out:
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/pyrender/viewer.py", line 1016, in _init_and_start_app
#     super(Viewer, self).__init__(config=conf, resizable=True,
#   File "/usr/local/lib/python3.11/dist-packages/pyglet/window/xlib/__init__.py", line 167, in __init__
#     super().__init__(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/pyglet/window/__init__.py", line 508, in __init__
#     display = pyglet.display.get_display()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pyglet/display/__init__.py", line 77, in get_display
#     return Display()
#            ^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pyglet/display/xlib.py", line 93, in __init__
#     raise NoSuchDisplayException(f'Cannot connect to "{name}"')
# ...

# %%
import trimesh
import pyrender

def display_3d_model(model_path):
    mesh = trimesh.load(model_path)
    scene = pyrender.Scene()
    scene.add(pyrender.Mesh.from_trimesh(mesh))

    viewer = pyrender.Viewer(scene, use_raymond_lighting=True, run_in_thread=True)

# %%
trimesh
pyrender
np
# Out:
# <module 'numpy' from '/usr/local/lib/python3.11/dist-packages/numpy/__init__.py'>

# %%
with open("requirements.txt", "w") as f:
    f.write("trimesh\npyrender\nnumpy==1.26.4\n")

# %%
# !pip install -r requirements.txt

# %%
# !python main.py
# Out:
# Enter a text prompt: A SMALL TOY CAR
# Generating 3D model for: 'A SMALL TOY CAR'
# Exception in thread Thread-1 (_init_and_start_app):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/pyrender/viewer.py", line 1016, in _init_and_start_app
#     super(Viewer, self).__init__(config=conf, resizable=True,
#   File "/usr/local/lib/python3.11/dist-packages/pyglet/window/xlib/__init__.py", line 167, in __init__
#     super().__init__(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/pyglet/window/__init__.py", line 508, in __init__
#     display = pyglet.display.get_display()
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pyglet/display/__init__.py", line 77, in get_display
# ...
